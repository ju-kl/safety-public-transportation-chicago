# %% [markdown]
# Import and clean CTA data (for reference of .dbf to .csv transformation, see https://pypi.org/project/simpledbf/; perform $ pip install simpledbf)

# %%
# import relevant libraries
import pandas as pd
import dbfread
from simpledbf import Dbf5

# %% [markdown]
# Create city grid table to generate unique IDs for all crimes and CTA locations to match data across datasets

# %%
# @Peter: insert code for grid table generation here

# %%
# import CTA_BusStops.dbf
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-Bus-Stops-Shapefile/pxug-u72f
dbf1 = Dbf5('Datasets/CTA_BusStops.dbf', codec='utf-8')

# %%
# take a look at the file
dbf1.fields
# Out:
# [('DeletionFlag', 'C', 1),
#  ('OBJECTID', 'N', 10),
#  ('SYSTEMSTOP', 'N', 19),
#  ('STREET', 'C', 75),
#  ('CROSS_ST', 'C', 75),
#  ('DIR', 'C', 3),
#  ('POS', 'C', 4),
#  ('ROUTESSTPG', 'C', 75),
#  ('OWLROUTES', 'C', 20),
#  ('CITY', 'C', 20),
#  ('STATUS', 'N', 10),
#  ('PUBLIC_NAM', 'C', 75),
#  ('POINT_X', 'N', 19),
#  ('POINT_Y', 'N', 19)]

# %%
# export .dbf file to .csv (BusStops)
dbf1.to_csv('Datasets/CTA_BusStops.csv')

# %%
# read .csv for BusStops
BusStops = pd.read_csv('Datasets/CTA_BusStops.csv', index_col = 'OBJECTID')

# %%
# change column name POINT_X and POINT_Y to lat and long
BusStops = BusStops.rename(columns={"POINT_X": "longitude", "POINT_Y":"latitude"})

# %%
# look at clean data frame
BusStops.head()
# Out:
#           SYSTEMSTOP   STREET            CROSS_ST DIR POS ROUTESSTPG  \
# OBJECTID
# 193           6696.0   TAYLOR              THROOP  EB  NS        157
# 194             22.0  JACKSON              KARLOV  EB  FS        126
# 195           4767.0   FOSTER          MONTICELLO  EB  NS         92
# 196           6057.0  ASHLAND  CERMAK/BLUE ISLAND  SB  NS       9,X9
# 197           1790.0    CLARK              ALBION  SB  NS         22
#
#          OWLROUTES     CITY  STATUS                    PUBLIC_NAM  longitude  \
# OBJECTID
# 193            NaN  CHICAGO       1               Taylor & Throop -87.659294
# 194            NaN  CHICAGO       1              Jackson & Karlov -87.727808
# 195            NaN  CHICAGO       1           Foster & Monticello -87.719780
# 196             N9  CHICAGO       1  Ashland & Cermak/Blue Island -87.666173
# 197            N22  CHICAGO       1                Clark & Albion -87.671981
#
#            latitude
# OBJECTID
# 193       41.869314
# 194       41.877007
# 195       41.975526
# 196       41.852484
# 197       42.001785

# %%
# import CTA_TrainStops.csv
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-System-Information-List-of-L-Stops/8pix-ypme
TrainStops = pd.read_csv('Datasets/CTA_TrainStops.csv', index_col = 'STOP_ID')
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O                 Location
# STOP_ID
# 30162    False  False  False  False   True  False  (41.857908, -87.669147)
# 30161    False  False  False  False   True  False  (41.857908, -87.669147)
# 30022    False  False  False  False  False   True  (41.829353, -87.680622)
# 30023    False  False  False  False  False   True  (41.829353, -87.680622)
# 30214    False  False  False  False  False  False  (41.831677, -87.625826)

# %%
# clean up TrainStations's Location column into Point_X and Point_Y
# split location column
LocationNew = TrainStops["Location"].str.split(",", n = 1, expand = True)
LocationNew.head()
# Out:
#                   0             1
# STOP_ID
# 30162    (41.857908   -87.669147)
# 30161    (41.857908   -87.669147)
# 30022    (41.829353   -87.680622)
# 30023    (41.829353   -87.680622)
# 30214    (41.831677   -87.625826)

# %%
# remove parentheses
LocationNew[0].replace(regex=True,inplace=True,to_replace=r'\(',value=r'')
LocationNew[1].replace(regex=True,inplace=True,to_replace=r'\)',value=r'')
LocationNew.head()
# Out:
#                  0            1
# STOP_ID
# 30162    41.857908   -87.669147
# 30161    41.857908   -87.669147
# 30022    41.829353   -87.680622
# 30023    41.829353   -87.680622
# 30214    41.831677   -87.625826

# %%
# add Point_Y and Point_X to dataframe
TrainStops["latitude"] = LocationNew[0]
TrainStops["longitude"] = LocationNew[1]
TrainStops = TrainStops.drop("Location", 1)

# %%
# look at clean data frame
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O   latitude    longitude
# STOP_ID
# 30162    False  False  False  False   True  False  41.857908   -87.669147
# 30161    False  False  False  False   True  False  41.857908   -87.669147
# 30022    False  False  False  False  False   True  41.829353   -87.680622
# 30023    False  False  False  False  False   True  41.829353   -87.680622
# 30214    False  False  False  False  False  False  41.831677   -87.625826

# %% [markdown]
# Establish API to crime data and clean it (perform pip install sodapy)

# %%
# import requests library
from sodapy import Socrata

# %%
# API instructions https://dev.socrata.com/foundry/data.cityofchicago.org/ijzp-q8t2
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                  "QtMhXqaTTglPlVS3AC6PEQQxD", username = "juli.kleindiek@gmail.com", password = "DEPA_2019")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("ijzp-q8t2", limit=10) # WE NEED TO CHANGE THIS TO ALL DATA

# %%
results[1]
# Out:
# {'id': '11882415',
#  'case_number': 'JC498901',
#  'date': '2019-11-03T23:46:00.000',
#  'block': '067XX S PRAIRIE AVE',
#  'iucr': '2820',
#  'primary_type': 'OTHER OFFENSE',
#  'description': 'TELEPHONE THREAT',
#  'location_description': 'RESIDENCE',
#  'arrest': False,
#  'domestic': False,
#  'beat': '0322',
#  'district': '003',
#  'ward': '20',
#  'community_area': '69',
#  'fbi_code': '08A',
#  'x_coordinate': '1179200',
#  'y_coordinate': '1860416',
#  'year': '2019',
#  'updated_on': '2019-11-10T15:57:53.000',
#  'latitude': '41.772270181',
#  'longitude': '-87.618656263',
#  'location': {'latitude': '41.772270181',
#   'longitude': '-87.618656263',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#  ':@computed_region_awaf_s7ux': '53',
#  ':@computed_region_6mkv_f3dw': '22260',
#  ':@computed_region_vrxf_vc4k': '67',
#  ':@computed_region_bdys_3d7i': '514',
#  ':@computed_region_43wa_7qmu': '32',
#  ':@computed_region_rpca_8um6': '60',
#  ':@computed_region_d9mm_jgwp': '18',
#  ':@computed_region_d3ds_rm58': '211'}

# %%
# Convert results to pandas DataFrame
crime_dirty = pd.DataFrame.from_records(results)

# %%
crime_dirty.head()
# Out:
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                           2                       22257
# 1                          32                       22260
# 2                           3                       14924
# 3                          46                       14926
# 4                          50                       21869
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          19                         297
# 1                          53                         514
# 2                          53                         706
# 3                          41                         290
# 4                          20                         128
#
#   :@computed_region_d3ds_rm58 :@computed_region_d9mm_jgwp  \
# 0                         266                          17
# 1                         211                          18
# 2                         108                          23
# 3                         198                          14
# 4                          58                          12
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  arrest  beat  ...  \
# 0                          23                          65   False  0713  ...
# 1                          60                          67   False  0322  ...
# 2                          37                          59    True  0924  ...
# 3                          54                          37   False  1821  ...
# 4                          48                          11   False  1623  ...
#
#        latitude                                           location  \
# 0  41.786873855  {'latitude': '41.786873855', 'longitude': '-87...
# 1  41.772270181  {'latitude': '41.772270181', 'longitude': '-87...
# 2  41.808541937  {'latitude': '41.808541937', 'longitude': '-87...
# 3   41.90982326  {'latitude': '41.90982326', 'longitude': '-87....
# 4  41.977260426  {'latitude': '41.977260426', 'longitude': '-87...
#
#   location_description      longitude   primary_type               updated_on  \
# 0          GAS STATION  -87.655550394        BATTERY  2019-11-10T15:57:53.000
# 1            RESIDENCE  -87.618656263  OTHER OFFENSE  2019-11-10T15:57:53.000
# 2               STREET  -87.671417223      NARCOTICS  2019-11-10T15:57:53.000
# 3        BAR OR TAVERN  -87.634670006        BATTERY  2019-11-10T15:57:53.000
# 4               STREET  -87.759614054          THEFT  2019-11-10T15:57:53.000
#
#    ward x_coordinate y_coordinate  year
# 0    16      1169094      1865656  2019
# 1    20      1179200      1860416  2019
# 2    15      1164706      1873518  2019
# 3    27      1174424      1910504  2019
# 4    45      1140250      1934826  2019
#
# [5 rows x 30 columns]

# %%
# investigate crime_dirty
crime_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 30 columns):
# :@computed_region_43wa_7qmu    10 non-null object
# :@computed_region_6mkv_f3dw    10 non-null object
# :@computed_region_awaf_s7ux    10 non-null object
# :@computed_region_bdys_3d7i    10 non-null object
# :@computed_region_d3ds_rm58    10 non-null object
# :@computed_region_d9mm_jgwp    10 non-null object
# :@computed_region_rpca_8um6    10 non-null object
# :@computed_region_vrxf_vc4k    10 non-null object
# arrest                         10 non-null bool
# beat                           10 non-null object
# block                          10 non-null object
# case_number                    10 non-null object
# community_area                 10 non-null object
# date                           10 non-null object
# description                    10 non-null object
# district                       10 non-null object
# domestic                       10 non-null bool
# fbi_code                       10 non-null object
# id                             10 non-null object
# iucr                           10 non-null object
# latitude                       10 non-null object
# location                       10 non-null object
# location_description           10 non-null object
# longitude                      10 non-null object
# primary_type                   10 non-null object
# updated_on                     10 non-null object
# ward                           10 non-null object
# x_coordinate                   10 non-null object
# y_coordinate                   10 non-null object
# year                           10 non-null object
# dtypes: bool(2), object(28)
# memory usage: 2.3+ KB

# %%
# validate the values , i.e. 'id'
crime_dirty.loc[2:3]['id']
# Out:
# 2    11881227
# 3    11881236
# Name: id, dtype: object

# %%
# bring dataframe into proper format
crime = crime_dirty[['id', 
        'case_number', 
        'date', 
        'block', 
        'iucr', 
        'primary_type', 
        'description', 
        'location_description',
        'arrest',
        'domestic',
        'beat',
        'district',
        'ward',
        'community_area',
        'fbi_code',
        'x_coordinate',
        'y_coordinate',
        'year',
        'updated_on',
        'latitude',
        'longitude']]

# %%
# take a look at the proper dataframe
crime.head()
# Out:
#          id case_number                     date                block  iucr  \
# 0  11881267    JC497620  2019-11-03T23:47:00.000      012XX W 59TH ST  0460
# 1  11882415    JC498901  2019-11-03T23:46:00.000  067XX S PRAIRIE AVE  2820
# 2  11881227    JC497637  2019-11-03T23:43:00.000      018XX W 47TH ST  2022
# 3  11881236    JC497629  2019-11-03T23:34:00.000     015XX N WELLS ST  0460
# 4  11881411    JC497826  2019-11-03T23:30:00.000   052XX N LARNED AVE  0810
#
#     primary_type       description location_description  arrest  domestic  \
# 0        BATTERY            SIMPLE          GAS STATION   False     False
# 1  OTHER OFFENSE  TELEPHONE THREAT            RESIDENCE   False     False
# 2      NARCOTICS     POSS: COCAINE               STREET    True     False
# 3        BATTERY            SIMPLE        BAR OR TAVERN   False     False
# 4          THEFT         OVER $500               STREET   False     False
#
#    ... district ward community_area fbi_code x_coordinate y_coordinate  year  \
# 0  ...      007   16             67      08B      1169094      1865656  2019
# 1  ...      003   20             69      08A      1179200      1860416  2019
# 2  ...      009   15             61       18      1164706      1873518  2019
# 3  ...      018   27              8      08B      1174424      1910504  2019
# 4  ...      016   45             11       06      1140250      1934826  2019
#
#                 updated_on      latitude      longitude
# 0  2019-11-10T15:57:53.000  41.786873855  -87.655550394
# 1  2019-11-10T15:57:53.000  41.772270181  -87.618656263
# 2  2019-11-10T15:57:53.000  41.808541937  -87.671417223
# 3  2019-11-10T15:57:53.000   41.90982326  -87.634670006
# 4  2019-11-10T15:57:53.000  41.977260426  -87.759614054
#
# [5 rows x 21 columns]

# %%
# rename column 'id' into 'crimeID'
crime = crime.rename(columns={"id": "crimeID"})

# %%
# define proper data types for each column; WE NEED FURTHER CLEANING HERE
crime = crime.astype({"crimeID": int})

# %%
# set index of crime dataframe to 'id'
crime.set_index('crimeID')
# Out:
#          case_number                     date                   block  iucr  \
# crimeID
# 11881267    JC497620  2019-11-03T23:47:00.000         012XX W 59TH ST  0460
# 11882415    JC498901  2019-11-03T23:46:00.000     067XX S PRAIRIE AVE  2820
# 11881227    JC497637  2019-11-03T23:43:00.000         018XX W 47TH ST  2022
# 11881236    JC497629  2019-11-03T23:34:00.000        015XX N WELLS ST  0460
# 11881411    JC497826  2019-11-03T23:30:00.000      052XX N LARNED AVE  0810
# 11883143    JC499975  2019-11-03T23:30:00.000         009XX E 47TH ST  0890
# 11881229    JC497646  2019-11-03T23:30:00.000         014XX W 72ND ST  0810
# 11881264    JC497624  2019-11-03T23:30:00.000  034XX W IRVING PARK RD  0420
# 11882005    JC498119  2019-11-03T23:30:00.000      115XX S HALSTED ST  0560
# 11881279    JC497608  2019-11-03T23:25:00.000   009XX W FULLERTON AVE  0312
#
#            primary_type                     description location_description  \
# crimeID
# 11881267        BATTERY                          SIMPLE          GAS STATION
# 11882415  OTHER OFFENSE                TELEPHONE THREAT            RESIDENCE
# 11881227      NARCOTICS                   POSS: COCAINE               STREET
# 11881236        BATTERY                          SIMPLE        BAR OR TAVERN
# 11881411          THEFT                       OVER $500               STREET
# 11883143          THEFT                   FROM BUILDING            RESIDENCE
# 11881229          THEFT                       OVER $500             SIDEWALK
# 11881264        BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR             SIDEWALK
# 11882005        ASSAULT                          SIMPLE          GAS STATION
# 11881279        ROBBERY  ARMED:KNIFE/CUTTING INSTRUMENT            CTA TRAIN
#
#           arrest  domestic  beat district ward community_area fbi_code  \
# crimeID
# 11881267   False     False  0713      007   16             67      08B
# 11882415   False     False  0322      003   20             69      08A
# 11881227    True     False  0924      009   15             61       18
# 11881236   False     False  1821      018   27              8      08B
# 11881411   False     False  1623      016   45             11       06
# 11883143   False     False  0222      002    4             39       06
# 11881229   False     False  0734      007   17             67       06
# 11881264    True     False  1723      017   35             16      04B
# 11882005   False     False  0524      005   34             53      08A
# 11881279   False     False  1812      018   43              7       03
#
#          x_coordinate y_coordinate  year               updated_on  \
# crimeID
# 11881267      1169094      1865656  2019  2019-11-10T15:57:53.000
# 11882415      1179200      1860416  2019  2019-11-10T15:57:53.000
# 11881227      1164706      1873518  2019  2019-11-10T15:57:53.000
# 11881236      1174424      1910504  2019  2019-11-10T15:57:53.000
# 11881411      1140250      1934826  2019  2019-11-10T15:57:53.000
# 11883143      1183500      1874048  2019  2019-11-10T15:57:53.000
# 11881229      1167647      1856992  2019  2019-11-10T15:57:53.000
# 11881264      1152544      1926374  2019  2019-11-10T15:57:53.000
# 11882005      1173048      1828494  2019  2019-11-10T15:57:53.000
# 11881279      1169577      1916141  2019  2019-11-10T15:57:53.000
#
#               latitude      longitude
# crimeID
# 11881267  41.786873855  -87.655550394
# 11882415  41.772270181  -87.618656263
# 11881227  41.808541937  -87.671417223
# 11881236   41.90982326  -87.634670006
# 11881411  41.977260426  -87.759614054
# 11883143  41.809578412  -87.602469089
# 11881229   41.76312992  -87.661104189
# 11881264  41.953832746  -87.714627461
# 11882005  41.684809877  -87.642147208
# 11881279  41.925398449  -87.652311296

# %% [markdown]
# Import and clead holiday data

# %%
# @Lola: insert code for loading holiday data

# %% [markdown]
# Establie API to weather data

# %%
# @Lola: insert code for for establishing API to weather data

# %% [markdown]
# Establish connection to GCP CouldSQL

# %%
# import required package
import pyodbc

# %%
# define connection to the server
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=server_name;'
                      'Database=db_name;'
                      'Trusted_Connection=yes;')

# %%
# define cursor
cursor = conn.cursor()

# %%
# examplary query
cursor.execute('SELECT * FROM db_name.Table')
