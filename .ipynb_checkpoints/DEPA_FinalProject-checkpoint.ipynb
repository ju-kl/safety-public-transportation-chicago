# %% [markdown]
# Step 0: Import all relevant libraries used in this project

# %% [markdown]
# Step 1: Download crime data related to CTA from the City of Chicago data portal API until November 15, 2019

# %% [markdown]
# Step 2: Clean the crime data

# %% [markdown]
# Step 3: Create Grid Table based on crime data

# %% [markdown]
# Step 4: Assign GridID to crime data

# %% [markdown]
# Step 5: Load BusStop and TrainStop data

# %% [markdown]
# Step 6: Clean BusStop and TrainStop data

# %% [markdown]
# Step 7: Assign GridID to BusStop and TrainStop data

# %% [markdown]
# Step 8: Load holiday data

# %% [markdown]
# Step 9: Clean holiday data

# %% [markdown]
# Step 10: Load tables into CloudSQL

# %% [markdown]
# Step 11: Daily refresh of crime data

# %% [markdown]
# Step 12: Clean daily updated crime data

# %% [markdown]
# Step 13: Assign GridID to daily updated crime data

# %% [markdown]
# Step 14: Append daily updated crime data to the crime database in CloudSQL

# %% [markdown]
# Import and clean CTA data (for reference of .dbf to .csv transformation, see https://pypi.org/project/simpledbf/; perform $ pip install simpledbf)

# %%
# import relevant libraries
import pandas as pd
import dbfread
from simpledbf import Dbf5

# %% [markdown]
# Create city grid table to generate unique IDs for all crimes and CTA locations to match data across datasets

# %%
# @Peter: insert code for grid table generation here

# %%
# import CTA_BusStops.dbf
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-Bus-Stops-Shapefile/pxug-u72f
dbf1 = Dbf5('Datasets/CTA_BusStops.dbf', codec='utf-8')

# %%
# take a look at the file
dbf1.fields
# Out:
# [('DeletionFlag', 'C', 1),
#  ('OBJECTID', 'N', 10),
#  ('SYSTEMSTOP', 'N', 19),
#  ('STREET', 'C', 75),
#  ('CROSS_ST', 'C', 75),
#  ('DIR', 'C', 3),
#  ('POS', 'C', 4),
#  ('ROUTESSTPG', 'C', 75),
#  ('OWLROUTES', 'C', 20),
#  ('CITY', 'C', 20),
#  ('STATUS', 'N', 10),
#  ('PUBLIC_NAM', 'C', 75),
#  ('POINT_X', 'N', 19),
#  ('POINT_Y', 'N', 19)]

# %%
# export .dbf file to .csv (BusStops)
dbf1.to_csv('Datasets/CTA_BusStops.csv')

# %%
# read .csv for BusStops
BusStops = pd.read_csv('Datasets/CTA_BusStops.csv', index_col = 'OBJECTID')

# %%
# change column name POINT_X and POINT_Y to lat and long
BusStops = BusStops.rename(columns={"POINT_X": "longitude", "POINT_Y":"latitude"})

# %%
# look at clean data frame
BusStops.head()
# Out:
#           SYSTEMSTOP   STREET            CROSS_ST DIR POS ROUTESSTPG  \
# OBJECTID
# 193           6696.0   TAYLOR              THROOP  EB  NS        157
# 194             22.0  JACKSON              KARLOV  EB  FS        126
# 195           4767.0   FOSTER          MONTICELLO  EB  NS         92
# 196           6057.0  ASHLAND  CERMAK/BLUE ISLAND  SB  NS       9,X9
# 197           1790.0    CLARK              ALBION  SB  NS         22
#
#          OWLROUTES     CITY  STATUS                    PUBLIC_NAM  longitude  \
# OBJECTID
# 193            NaN  CHICAGO       1               Taylor & Throop -87.659294
# 194            NaN  CHICAGO       1              Jackson & Karlov -87.727808
# 195            NaN  CHICAGO       1           Foster & Monticello -87.719780
# 196             N9  CHICAGO       1  Ashland & Cermak/Blue Island -87.666173
# 197            N22  CHICAGO       1                Clark & Albion -87.671981
#
#            latitude
# OBJECTID
# 193       41.869314
# 194       41.877007
# 195       41.975526
# 196       41.852484
# 197       42.001785

# %%
# import CTA_TrainStops.csv
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-System-Information-List-of-L-Stops/8pix-ypme
TrainStops = pd.read_csv('Datasets/CTA_TrainStops.csv', index_col = 'STOP_ID')
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O                 Location
# STOP_ID
# 30162    False  False  False  False   True  False  (41.857908, -87.669147)
# 30161    False  False  False  False   True  False  (41.857908, -87.669147)
# 30022    False  False  False  False  False   True  (41.829353, -87.680622)
# 30023    False  False  False  False  False   True  (41.829353, -87.680622)
# 30214    False  False  False  False  False  False  (41.831677, -87.625826)

# %%
# clean up TrainStations's Location column into Point_X and Point_Y
# split location column
LocationNew = TrainStops["Location"].str.split(",", n = 1, expand = True)
LocationNew.head()
# Out:
#                   0             1
# STOP_ID
# 30162    (41.857908   -87.669147)
# 30161    (41.857908   -87.669147)
# 30022    (41.829353   -87.680622)
# 30023    (41.829353   -87.680622)
# 30214    (41.831677   -87.625826)

# %%
# remove parentheses
LocationNew[0].replace(regex=True,inplace=True,to_replace=r'\(',value=r'')
LocationNew[1].replace(regex=True,inplace=True,to_replace=r'\)',value=r'')
LocationNew.head()
# Out:
#                  0            1
# STOP_ID
# 30162    41.857908   -87.669147
# 30161    41.857908   -87.669147
# 30022    41.829353   -87.680622
# 30023    41.829353   -87.680622
# 30214    41.831677   -87.625826

# %%
# add Point_Y and Point_X to dataframe
TrainStops["latitude"] = LocationNew[0]
TrainStops["longitude"] = LocationNew[1]
TrainStops = TrainStops.drop("Location", 1)

# %%
# look at clean data frame
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O   latitude    longitude
# STOP_ID
# 30162    False  False  False  False   True  False  41.857908   -87.669147
# 30161    False  False  False  False   True  False  41.857908   -87.669147
# 30022    False  False  False  False  False   True  41.829353   -87.680622
# 30023    False  False  False  False  False   True  41.829353   -87.680622
# 30214    False  False  False  False  False  False  41.831677   -87.625826

# %% [markdown]
# Establish API to crime data and clean it (perform pip install sodapy)

# %%
# import requests library
from sodapy import Socrata

# %%
# API instructions https://dev.socrata.com/foundry/data.cityofchicago.org/ijzp-q8t2
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                  "QtMhXqaTTglPlVS3AC6PEQQxD", username = "juli.kleindiek@gmail.com", password = "DEPA_2019")

# Limit to 6000 rows to avoid time out errors, data has <6000 rows, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("5xiy-qnsz", limit = 6000)

# %%
results[1]
# Out:
# {':@computed_region_d9mm_jgwp': '7',
#  ':@computed_region_43wa_7qmu': '40',
#  'date': '2011-03-20T13:00:00.000',
#  'location': {'latitude': '41.913644076',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}',
#   'needs_recoding': False,
#   'longitude': '-87.687306326'},
#  'district': '014',
#  'y_coordinate': '1911784',
#  'block': '017XX N WESTERN AVE',
#  ':@computed_region_rpca_8um6': '1',
#  'latitude': '41.913644076',
#  ':@computed_region_awaf_s7ux': '24',
#  'description': 'CREDIT CARD FRAUD',
#  'location_description': 'CTA BUS',
#  'community_area': '24',
#  'updated_on': '2018-02-10T15:50:01.000',
#  'iucr': '1150',
#  'x_coordinate': '1160086',
#  'ward': '1',
#  'year': '2011',
#  'case_number': 'HT212010',
#  'fbi_code': '11',
#  'domestic': False,
#  'longitude': '-87.687306326',
#  ':@computed_region_bdys_3d7i': '298',
#  'beat': '1434',
#  ':@computed_region_6mkv_f3dw': '22535',
#  'arrest': False,
#  'primary_type': 'DECEPTIVE PRACTICE',
#  ':@computed_region_vrxf_vc4k': '25',
#  'id': '7979411',
#  ':@computed_region_d3ds_rm58': '192'}

# %%
# Convert results to pandas DataFrame
crime_dirty = pd.DataFrame.from_records(results)

# %%
crime_dirty.head()
# Out:
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                          36                        4452
# 1                          40                       22535
# 2                          14                       21569
# 3                          13                       21554
# 4                           1                       21569
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          22                         784
# 1                          24                         298
# 2                          36                         772
# 3                          18                         531
# 4                          14                         261
#
#   :@computed_region_d3ds_rm58 :@computed_region_d9mm_jgwp  \
# 0                          91                          22
# 1                         192                           7
# 2                         153                          21
# 3                         233                          20
# 4                         130                          21
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  arrest  beat  ...  \
# 0                          45                          29   False  0111  ...
# 1                           1                          25   False  1434  ...
# 2                          57                          30   False  1021  ...
# 3                          59                          70   False  0613  ...
# 4                          57                          32   False  1033  ...
#
#        latitude                                           location  \
# 0  41.882189946  {'latitude': '41.882189946', 'human_address': ...
# 1  41.913644076  {'latitude': '41.913644076', 'human_address': ...
# 2  41.859020037  {'latitude': '41.859020037', 'human_address': ...
# 3  41.735931109  {'latitude': '41.735931109', 'human_address': ...
# 4  41.847153749  {'latitude': '41.847153749', 'human_address': ...
#
#   location_description      longitude        primary_type  \
# 0              CTA BUS  -87.641202862             BATTERY
# 1              CTA BUS  -87.687306326  DECEPTIVE PRACTICE
# 2              CTA BUS  -87.710681986               THEFT
# 3              CTA BUS  -87.653642482               THEFT
# 4              CTA BUS   -87.70511925             ROBBERY
#
#                 updated_on  ward x_coordinate y_coordinate  year
# 0  2018-02-10T15:50:01.000    42      1172727      1900420  2011
# 1  2018-02-10T15:50:01.000     1      1160086      1911784  2011
# 2  2018-02-10T15:50:01.000    24      1153868      1891832  2011
# 3  2018-02-10T15:50:01.000    21      1169761      1847097  2011
# 4  2018-02-10T15:50:01.000    24      1155415      1887519  2011
#
# [5 rows x 30 columns]

# %%
# investigate crime_dirty
crime_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5808 entries, 0 to 5807
# Data columns (total 30 columns):
# :@computed_region_43wa_7qmu    5803 non-null object
# :@computed_region_6mkv_f3dw    5806 non-null object
# :@computed_region_awaf_s7ux    5803 non-null object
# :@computed_region_bdys_3d7i    5790 non-null object
# :@computed_region_d3ds_rm58    5803 non-null object
# :@computed_region_d9mm_jgwp    5803 non-null object
# :@computed_region_rpca_8um6    5803 non-null object
# :@computed_region_vrxf_vc4k    5803 non-null object
# arrest                         5808 non-null bool
# beat                           5808 non-null object
# block                          5808 non-null object
# case_number                    5808 non-null object
# community_area                 5808 non-null object
# date                           5808 non-null object
# description                    5808 non-null object
# district                       5808 non-null object
# domestic                       5808 non-null bool
# fbi_code                       5808 non-null object
# id                             5808 non-null object
# iucr                           5808 non-null object
# latitude                       5806 non-null object
# location                       5806 non-null object
# location_description           5808 non-null object
# longitude                      5806 non-null object
# primary_type                   5808 non-null object
# updated_on                     5808 non-null object
# ward                           5808 non-null object
# x_coordinate                   5806 non-null object
# y_coordinate                   5806 non-null object
# year                           5808 non-null object
# dtypes: bool(2), object(28)
# memory usage: 1.3+ MB

# %%
# validate the values , i.e. 'id'
crime_dirty.loc[2:3]['id']
# Out:
# 2    7981270
# 3    7979660
# Name: id, dtype: object

# %%
# bring dataframe into proper format
crime = crime_dirty[['id', 
        'case_number', 
        'date', 
        'block', 
        'iucr', 
        'primary_type', 
        'description', 
        'location_description',
        'arrest',
        'domestic',
        'beat',
        'district',
        'ward',
        'community_area',
        'fbi_code',
        'x_coordinate',
        'y_coordinate',
        'year',
        'updated_on',
        'latitude',
        'longitude']]

# %%
# take a look at the proper dataframe
crime.head()
# Out:
#         id case_number                     date                block  iucr  \
# 0  8256302    HT490196  2011-09-10T12:46:00.000   0000X N CLINTON ST  0460
# 1  7979411    HT212010  2011-03-20T13:00:00.000  017XX N WESTERN AVE  1150
# 2  7981270    HT213521  2011-03-20T15:00:00.000      034XX W 16TH ST  0820
# 3  7979660    HT212325  2011-03-20T20:09:00.000      012XX W 87TH ST  0820
# 4  7989927    HT213271  2011-03-20T20:57:00.000   024XX S KEDZIE AVE  033A
#
#          primary_type             description location_description  arrest  \
# 0             BATTERY                  SIMPLE              CTA BUS   False
# 1  DECEPTIVE PRACTICE       CREDIT CARD FRAUD              CTA BUS   False
# 2               THEFT          $500 AND UNDER              CTA BUS   False
# 3               THEFT          $500 AND UNDER              CTA BUS   False
# 4             ROBBERY  ATTEMPT: ARMED-HANDGUN              CTA BUS   False
#
#    domestic  ... district ward community_area fbi_code x_coordinate  \
# 0     False  ...      001   42             28      08B      1172727
# 1     False  ...      014    1             24       11      1160086
# 2     False  ...      010   24             29       06      1153868
# 3     False  ...      006   21             71       06      1169761
# 4     False  ...      010   24             30       03      1155415
#
#   y_coordinate  year               updated_on      latitude      longitude
# 0      1900420  2011  2018-02-10T15:50:01.000  41.882189946  -87.641202862
# 1      1911784  2011  2018-02-10T15:50:01.000  41.913644076  -87.687306326
# 2      1891832  2011  2018-02-10T15:50:01.000  41.859020037  -87.710681986
# 3      1847097  2011  2018-02-10T15:50:01.000  41.735931109  -87.653642482
# 4      1887519  2011  2018-02-10T15:50:01.000  41.847153749   -87.70511925
#
# [5 rows x 21 columns]

# %%
# rename column 'id' into 'crimeID'
crime = crime.rename(columns={"id": "crimeID"})

# %%
# define proper data types for each column; WE NEED FURTHER CLEANING HERE
crime = crime.astype({"crimeID": int})

# %%
# set index of crime dataframe to 'id'
crime.set_index('crimeID')
# Out:
#         case_number                     date  \
# crimeID
# 8256302    HT490196  2011-09-10T12:46:00.000
# 7979411    HT212010  2011-03-20T13:00:00.000
# 7981270    HT213521  2011-03-20T15:00:00.000
# 7979660    HT212325  2011-03-20T20:09:00.000
# 7989927    HT213271  2011-03-20T20:57:00.000
# 8332454    HT566424  2011-10-30T09:00:00.000
# 8332084    HT566137  2011-10-30T02:08:00.000
# 7905059    HT134917  2011-01-25T14:30:00.000
#
#                             description location_description  arrest  \
# crimeID
# 8256302                          SIMPLE              CTA BUS   False
# 7979411               CREDIT CARD FRAUD              CTA BUS   False
# 7981270                  $500 AND UNDER              CTA BUS   False
# 7979660                  $500 AND UNDER              CTA BUS   False
# 7989927          ATTEMPT: ARMED-HANDGUN              CTA BUS   False
# 8332454                          SIMPLE              CTA BUS   False
# 8332084                          SIMPLE              CTA BUS    True
# 7905059         DOMESTIC BATTERY SIMPLE              CTA BUS   False
# 7906391                          SIMPLE              CTA BUS   False
# 7982963                  POCKET-PICKING              CTA BUS   False
# 7908516                          SIMPLE              CTA BUS   False
# 7981295                  POCKET-PICKING              CTA BUS   False
# 8331651     PRO EMP HANDS NO/MIN INJURY              CTA BUS   False
# 7986020                       OVER $500              CTA BUS   False
# 7869656                          SIMPLE              CTA BUS   False
# 7907026         HARASSMENT BY TELEPHONE              CTA BUS   False
# 8413942                          SIMPLE              CTA BUS   False
# 7982740                          SIMPLE              CTA BUS   False
# 7878859   AGGRAVATED: OTHER DANG WEAPON              CTA BUS    True
# 8394910                         TO LAND              CTA BUS    True
# 7992546                  POCKET-PICKING              CTA BUS   False
# 7879112                  POCKET-PICKING              CTA BUS   False
# 8336007                  POCKET-PICKING              CTA BUS   False
# 7905408         THEFT OF LABOR/SERVICES              CTA BUS   False
# 7983371                          SIMPLE              CTA BUS    True
# 7878942                          SIMPLE              CTA BUS    True
# 8331626         HARASSMENT BY TELEPHONE              CTA BUS   False
# 7998824                          SIMPLE              CTA BUS   False
# 7985598         DOMESTIC BATTERY SIMPLE              CTA BUS   False
# 7984685             AGGRAVATED: HANDGUN              CTA BUS    True
# ...                                 ...                  ...     ...
# 8365807                  POCKET-PICKING            CTA TRAIN   False
# 8286302                       OVER $500            CTA TRAIN   False
# 8042760           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8286530           STRONGARM - NO WEAPON            CTA TRAIN   False
# 7884268                       OVER $500            CTA TRAIN   False
# 8041871           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8287063           CRIMINAL SEXUAL ABUSE            CTA TRAIN   False
# 8287777                  $500 AND UNDER            CTA TRAIN   False
# 8363496                       OVER $500            CTA TRAIN   False
# 8050706           STRONGARM - NO WEAPON            CTA TRAIN   False
# 7901689               CREDIT CARD FRAUD            CTA TRAIN   False
# 8404754           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8041693                       OVER $500            CTA TRAIN   False
# 8041382    POSS: CANNABIS 30GMS OR LESS            CTA TRAIN    True
# 8041186                  POCKET-PICKING            CTA TRAIN   False
# 8043164           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8042116           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8041675                  $500 AND UNDER            CTA TRAIN   False
# 8363498    POSS: CANNABIS 30GMS OR LESS            CTA TRAIN    True
# 8041066      THEFT OF LOST/MISLAID PROP            CTA TRAIN    True
# 8041012  ARMED:KNIFE/CUTTING INSTRUMENT            CTA TRAIN   False
# 7942334    POSS: CANNABIS 30GMS OR LESS            CTA TRAIN    True
# 8040503           STRONGARM - NO WEAPON            CTA TRAIN   False
# 8292360                       OVER $500            CTA TRAIN   False
# 8041186      1921071  2011  2018-02-10T15:50:01.000  41.939270274
# 8043164      1881827  2011  2018-02-10T15:50:01.000  41.831051803
# 8042116      1916141  2011  2018-02-10T15:50:01.000  41.925398601
# 8041675      1921560  2011  2018-02-10T15:50:01.000  41.940251326
# 8363498      1905805  2011  2016-02-04T06:33:39.000  41.896888586
# 8041066      1910783  2011  2018-02-10T15:50:01.000  41.910676312
# 8041012      1871216  2011  2018-02-10T15:50:01.000  41.802474721
# 7942334      1881773  2011  2018-02-10T15:50:01.000  41.830954079
# 8040503      1868295  2011  2018-02-10T15:50:01.000  41.793935909
# 8292360      1899156  2011  2018-02-10T15:50:01.000  41.878638996
# 7970249      1950023  2011  2018-02-10T15:50:01.000  42.018498254
# 8367340      1939683  2011  2018-02-10T15:50:01.000  41.990041584
# 8363919      1897829  2011  2018-02-10T15:50:01.000  41.875286899
# 8288014      1901501  2011  2018-02-10T15:50:01.000  41.885312381
# 8040839      1939379  2011  2018-02-10T15:50:01.000  41.989243623
# 8398367      1897399  2011  2016-02-04T06:33:39.000  41.874288203
#
#              longitude
# crimeID
# 8256302  -87.641202862
# 7979411  -87.687306326
# 7981270  -87.710681986
# 7979660  -87.653642482
# 7989927   -87.70511925
# 8332454   -87.64458443
# 8332084  -87.624485177
# 7905059  -87.630898966
# 7906391  -87.695433299
# 7982963   -87.60829647
# 7908516  -87.579965641
# 7981295  -87.726984558
# 8331651  -87.764650028
# 7986020  -87.627938154
# 7869656  -87.666473716
# 7907026  -87.658588247
# 8413942  -87.663460692
# 7982740  -87.627706271
# 7878859  -87.604556978
# 8394910  -87.613699222
# 7992546  -87.624485177
# 7879112  -87.768778958
# 8336007  -87.709704762
# 7905408  -87.625185222
# 7983371  -87.601657723
# 7878942  -87.628256304
# 8331626  -87.624152861
# 7998824  -87.616576329
# 7985598  -87.706612089
# 7984685  -87.662925738
# ...                ...
# 8365807  -87.628061509
# 8286302   -87.62741936
# 8042760  -87.632007113
# 8286530  -87.725430093
# 7884268  -87.638560993
# 8041871  -87.664206366
# 8287063  -87.626342565
# 8287777     -87.627633
# 8363496  -87.726422045
# 8050706  -87.630937377
# 7901689  -87.715470049
# 8404754  -87.631460067
# 8041693  -87.628061509
# 8041382   -87.62743954
# 8041186  -87.712794514
# 8043164  -87.622501311
# 8042116  -87.652337017
# 8041675  -87.649275328
# 8363498  -87.628203192
# 8041066  -87.649187069
# 8041012  -87.716349783
# 7942334  -87.630703226
# 8040503  -87.625680278
# 8292360  -87.627691486
# 7970249  -87.672983233
# 8367340   -87.65891695
# 8363919   -87.67649739
# 8288014  -87.667573631
# 8040839  -87.665119726
# 8398367  -87.709006362
#
# [5808 rows x 20 columns]

# %% [markdown]
# Import and clead holiday data

# %%
# @Lola: insert code for loading holiday data

# %% [markdown]
# Establie API to weather data

# %%
# @Lola: insert code for for establishing API to weather data

# %% [markdown]
# Establish connection to GCP CouldSQL

# %%
# import required package
import pyodbc

# %%
# define connection to the server
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=server_name;'
                      'Database=db_name;'
                      'Trusted_Connection=yes;')

# %%
# define cursor
cursor = conn.cursor()

# %%
# examplary query
cursor.execute('SELECT * FROM db_name.Table')
