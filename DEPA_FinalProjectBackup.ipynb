# %% [markdown]
# # Safety on Public Transportation in Chicago
#
# ### Authors: Jainam Mehta, Julian Kleindiek, Lola Johnston, Peter Eusebio
# ### Date: 12/06/2019

# %% [markdown]
# ## Step 1: Import all relevant libraries used in this project

# %%
from sodapy import Socrata # for API calls
import sqlalchemy as db # for SQL
import pymysql # for SQL
import pandas as pd # for data cleaning
import dbfread # for dbf transformation
from simpledbf import Dbf5 # for dbf transformation

# %% [markdown]
# ## Step 2: Download crime data related to CTA from the City of Chicago data portal API until November 15, 2019

# %%
## Change this to filter for CTA as description and where = "date <= '2019-11-15T00:00:00.000'"

## WARNING: this query takes approx. 3 minutes to run; don't run it everytime you run this script

# API instructions https://dev.socrata.com/foundry/data.cityofchicago.org/ijzp-q8t2
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                  "QtMhXqaTTglPlVS3AC6PEQQxD", username = "juli.kleindiek@gmail.com", password = "DEPA_2019")

# Limit to 6000 rows to avoid time out errors, data has <6000 rows, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
# Pull all crime data before '2019-11-15T00:00:00.000'
results = client.get("ijzp-q8t2", limit = 100)

# %% [markdown]
# ## Step 3: Clean the crime data

# %%
# Look at the output of the dowload
results[1]
# Out:
# {'id': '11888943',
#  'case_number': 'JC507109',
#  'date': '2019-11-11T23:22:00.000',
#  'block': '020XX W ADAMS ST',
#  'iucr': '0486',
#  'primary_type': 'BATTERY',
#  'description': 'DOMESTIC BATTERY SIMPLE',
#  'location_description': 'APARTMENT',
#  'arrest': True,
#  'domestic': True,
#  'beat': '1225',
#  'district': '012',
#  'ward': '27',
#  'community_area': '28',
#  'fbi_code': '08B',
#  'x_coordinate': '1162865',
#  'y_coordinate': '1899085',
#  'year': '2019',
#  'updated_on': '2019-11-18T16:00:37.000',
#  'latitude': '41.878739138',
#  'longitude': '-87.677453482',
#  'location': {'latitude': '41.878739138',
#   'longitude': '-87.677453482',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#  ':@computed_region_awaf_s7ux': '48',
#  ':@computed_region_6mkv_f3dw': '21184',
#  ':@computed_region_vrxf_vc4k': '29',
#  ':@computed_region_bdys_3d7i': '89',
#  ':@computed_region_43wa_7qmu': '46',
#  ':@computed_region_rpca_8um6': '28',
#  ':@computed_region_d9mm_jgwp': '15',
#  ':@computed_region_d3ds_rm58': '75'}

# %%
# Convert results to pandas DataFrame
crime_dirty = pd.DataFrame.from_records(results)
crime_dirty.head()
# Out:
#   :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                           4                       22260
# 1                          46                       21184
# 2                           7                       22216
# 3                          23                       21572
# 4                          30                        4300
#
#   :@computed_region_awaf_s7ux :@computed_region_bdys_3d7i  \
# 0                          53                         470
# 1                          48                          89
# 2                          52                          68
# 3                          36                         716
# 4                          23                         235
#
#   :@computed_region_d3ds_rm58 :@computed_region_d9mm_jgwp  \
# 0                         275                          18
# 1                          75                          15
# 2                          97                          25
# 3                         143                          16
# 4                         232                          13
#
#   :@computed_region_rpca_8um6 :@computed_region_vrxf_vc4k  arrest  beat  ...  \
# 0                          60                           9   False  0313  ...
# 1                          28                          29    True  1225  ...
# 2                          32                          26   False  1513  ...
# 3                          30                          27    True  1131  ...
# 4                           8                          69    True  0834  ...
#
#        latitude                                           location  \
# 0  41.782256768  {'latitude': '41.782256768', 'longitude': '-87...
# 1  41.878739138  {'latitude': '41.878739138', 'longitude': '-87...
# 2  41.879913063  {'latitude': '41.879913063', 'longitude': '-87...
# 3   41.87604254  {'latitude': '41.87604254', 'longitude': '-87....
# 4  41.747631383  {'latitude': '41.747631383', 'longitude': '-87...
#
#   location_description      longitude     primary_type  \
# 0             SIDEWALK  -87.601672158          ROBBERY
# 1            APARTMENT  -87.677453482          BATTERY
# 2            APARTMENT  -87.764855438  CRIMINAL DAMAGE
# 3               STREET  -87.736506226        NARCOTICS
# 4            RESIDENCE  -87.730584209          BATTERY
#
#                 updated_on  ward x_coordinate y_coordinate  year
# 0  2019-11-18T16:00:37.000    20      1183802      1864094  2019
# 1  2019-11-18T16:00:37.000    27      1162865      1899085  2019
# 2  2019-11-18T16:00:37.000    29      1139060      1899343  2019
# 3  2019-11-18T16:00:37.000    28      1146790      1897985  2019
# 4  2019-11-18T16:00:37.000    18      1148731      1851204  2019
#
# [5 rows x 30 columns]

# %%
# investigate crime_dirty 
crime_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 30 columns):
# :@computed_region_43wa_7qmu    92 non-null object
# :@computed_region_6mkv_f3dw    92 non-null object
# :@computed_region_awaf_s7ux    92 non-null object
# :@computed_region_bdys_3d7i    92 non-null object
# :@computed_region_d3ds_rm58    92 non-null object
# :@computed_region_d9mm_jgwp    92 non-null object
# :@computed_region_rpca_8um6    92 non-null object
# :@computed_region_vrxf_vc4k    92 non-null object
# arrest                         100 non-null bool
# beat                           100 non-null object
# block                          100 non-null object
# case_number                    100 non-null object
# community_area                 100 non-null object
# date                           100 non-null object
# description                    100 non-null object
# district                       100 non-null object
# domestic                       100 non-null bool
# fbi_code                       100 non-null object
# id                             100 non-null object
# iucr                           100 non-null object
# latitude                       92 non-null object
# location                       92 non-null object
# location_description           100 non-null object
# longitude                      92 non-null object
# primary_type                   100 non-null object
# updated_on                     100 non-null object
# ward                           100 non-null object
# x_coordinate                   92 non-null object
# y_coordinate                   92 non-null object
# year                           100 non-null object
# dtypes: bool(2), object(28)
# memory usage: 22.1+ KB

# %%
# Validate the values , i.e. 'id'
crime_dirty.loc[2:3]['id']
# Out:
# 2    11889016
# 3    11888939
# Name: id, dtype: object

# %%
# bring dataframe into proper format
crime = crime_dirty[['id', 
        'case_number', 
        'date', 
        'block', 
        'iucr', 
        'primary_type', 
        'description', 
        'location_description',
        'arrest',
        'domestic',
        'beat',
        'district',
        'ward',
        'community_area',
        'fbi_code',
        'x_coordinate',
        'y_coordinate',
        'year',
        'updated_on',
        'latitude',
        'longitude']]

# %%
# take a look at the proper dataframe
crime.head()
# Out:
#          id case_number                     date                block  iucr  \
# 0  11888984    JC507130  2019-11-11T23:59:00.000      009XX E 62ND ST  0313
# 1  11888943    JC507109  2019-11-11T23:22:00.000     020XX W ADAMS ST  0486
# 2  11889016    JC507117  2019-11-11T23:20:00.000  0000X S CENTRAL AVE  1310
# 3  11888939    JC507114  2019-11-11T23:18:00.000   044XX W GLADYS AVE  1821
# 4  11888972    JC507118  2019-11-11T23:10:00.000    079XX S KOLIN AVE  0486
#
#       primary_type                     description location_description  \
# 0          ROBBERY   ARMED: OTHER DANGEROUS WEAPON             SIDEWALK
# 1          BATTERY         DOMESTIC BATTERY SIMPLE            APARTMENT
# 2  CRIMINAL DAMAGE                     TO PROPERTY            APARTMENT
# 3        NARCOTICS  MANU/DEL:CANNABIS 10GM OR LESS               STREET
# 4          BATTERY         DOMESTIC BATTERY SIMPLE            RESIDENCE
#
#    arrest  domestic  ... district ward community_area fbi_code x_coordinate  \
# 0   False     False  ...      003   20             42       03      1183802
# 1    True      True  ...      012   27             28      08B      1162865
# 2   False     False  ...      015   29             25       14      1139060
# 3    True     False  ...      011   28             26       18      1146790
# 4    True      True  ...      008   18             70      08B      1148731
#
#   y_coordinate  year               updated_on      latitude      longitude
# 0      1864094  2019  2019-11-18T16:00:37.000  41.782256768  -87.601672158
# 1      1899085  2019  2019-11-18T16:00:37.000  41.878739138  -87.677453482
# 2      1899343  2019  2019-11-18T16:00:37.000  41.879913063  -87.764855438
# 3      1897985  2019  2019-11-18T16:00:37.000   41.87604254  -87.736506226
# 4      1851204  2019  2019-11-18T16:00:37.000  41.747631383  -87.730584209
#
# [5 rows x 21 columns]

# %%
# rename column 'id' into 'crimeID'
crime = crime.rename(columns={"id": "crimeID"})

# %%
# define proper data types for each column; WE NEED FURTHER CLEANING HERE
crime = crime.astype({"crimeID": int})

# %%
# set index of crime dataframe to 'id'
crime.set_index('crimeID')
# Out:
#          case_number                     date                      block  \
# crimeID
# 11888984    JC507130  2019-11-11T23:59:00.000            009XX E 62ND ST
# 11888943    JC507109  2019-11-11T23:22:00.000           020XX W ADAMS ST
# 11889016    JC507117  2019-11-11T23:20:00.000        0000X S CENTRAL AVE
# 11888939    JC507114  2019-11-11T23:18:00.000         044XX W GLADYS AVE
# 11888972    JC507118  2019-11-11T23:10:00.000          079XX S KOLIN AVE
# 11888981    JC507098  2019-11-11T23:05:00.000         002XX S CICERO AVE
# 11889666    JC507600  2019-11-11T23:00:00.000         038XX S WABASH AVE
# 11889034    JC507198  2019-11-11T23:00:00.000          059XX W SCHOOL ST
# 11891073    JC509906  2019-11-11T23:00:00.000          006XX E BOWEN AVE
# 11889316    JC507668  2019-11-11T23:00:00.000       035XX W LEXINGTON ST
# 11888948    JC507106  2019-11-11T23:00:00.000   073XX S STONY ISLAND AVE
# 11889769    JC507096  2019-11-11T22:55:00.000            010XX W 70TH ST
# 11888946    JC507092  2019-11-11T22:50:00.000           008XX W 111TH ST
# 11888935    JC507104  2019-11-11T22:50:00.000       011XX W JACKSON BLVD
# 11889261    JC507556  2019-11-11T22:45:00.000        041XX S CALUMET AVE
# 11889260    JC507220  2019-11-11T22:45:00.000           072XX S YALE AVE
# 11889762    JC507103  2019-11-11T22:43:00.000     076XX S SOUTH SHORE DR
# 11888937    JC507082  2019-11-11T22:41:00.000         042XX W MADISON ST
# 11894726    JC507083  2019-11-11T22:40:00.000       006XX N MICHIGAN AVE
# 11889260                                         TO VEHICLE
# 11889762                              AGGRAVATED OF A CHILD
# 11888937                           UNLAWFUL POSS OF HANDGUN
# 11894726                            THEFT OF LABOR/SERVICES
# 11888964                     POSS: CANNABIS MORE THAN 30GMS
# 11888988                      AGGRAVATED: OTHER DANG WEAPON
# 11889011                                             SIMPLE
# 11890092                                     $500 AND UNDER
# 11889377                            DOMESTIC BATTERY SIMPLE
# 11888998                                             SIMPLE
# 11888944                            DOMESTIC BATTERY SIMPLE
# 11889057                                         TO VEHICLE
# 11888919                                POSS: HEROIN(WHITE)
# 11888957                                             SIMPLE
# 11888906                            DOMESTIC BATTERY SIMPLE
# ...                                                     ...
# 11889185                            HARASSMENT BY TELEPHONE
# 11888862                     MANU/DEL:CANNABIS 10GM OR LESS
# 11890134                                        TO PROPERTY
# 11888953                                     $500 AND UNDER
# 11888920                                        TO PROPERTY
# 11888904                            DOMESTIC BATTERY SIMPLE
# 11889592                                       RETAIL THEFT
# 11888845                                            TO LAND
# 11888817                            HARASSMENT BY TELEPHONE
# 11888876                                        TO PROPERTY
# 11888884                                             SIMPLE
# 11889733                                  CREDIT CARD FRAUD
# 11892019                                             SIMPLE
# 11890513                                             SIMPLE
# 11888780                                     $500 AND UNDER
# 11889257                                        TO PROPERTY
# 11889077                                         AUTOMOBILE
# 11889567  NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IM...
# 11888942                                         TO VEHICLE
# 11888869                            DOMESTIC BATTERY SIMPLE
# 11888892                       POSS: CANNABIS 30GMS OR LESS
# 11888925                           UNLAWFUL POSS OF HANDGUN
# 11888898                           UNLAWFUL POSS OF HANDGUN
# 11888864                                            TO LAND
# 11888881                                             SIMPLE
# 11889962                            DOMESTIC BATTERY SIMPLE
# 11889108                                     $500 AND UNDER
# 11888751                            DOMESTIC BATTERY SIMPLE
# 11889271                                       RETAIL THEFT
# 11892046                                         AUTOMOBILE
#
#                     location_description  arrest  domestic  beat district  \
# crimeID
# 11888984                        SIDEWALK   False     False  0313      003
# 11888943                       APARTMENT    True      True  1225      012
# 11889016                       APARTMENT   False     False  1513      015
# 11888939                          STREET    True     False  1131      011
# 11888972                       RESIDENCE    True      True  0834      008
# 11888981                          STREET   False     False  1533      015
# 11889666          DRIVEWAY - RESIDENTIAL   False     False  0213      002
# 11889034                          STREET   False     False  1633      016
# 11891073                          STREET   False     False  0214      002
# 11889316                          STREET   False     False  1133      011
# 11888948       HOSPITAL BUILDING/GROUNDS    True     False  0324      003
# 11889769                       RESIDENCE   False      True  0733      007
# 11888946                      RESTAURANT    True     False  2233      022
# 11888935              GROCERY FOOD STORE    True     False  1232      012
# 11889261                       APARTMENT   False     False  0213      002
# 11889260                          STREET   False     False  0731      007
# 11889762                       APARTMENT   False      True  0421      004
# 11888937                          STREET    True     False  1115      011
# 11894726                      RESTAURANT   False     False  1834      018
# 11888964                          STREET    True     False  1524      015
# 11888988                       APARTMENT   False      True  0631      006
# 11889011                       RESIDENCE   False     False  0835      008
# 11890092          VEHICLE NON-COMMERCIAL   False     False  0624      006
# 11889377                       RESIDENCE   False     False  0232      002
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-Bus-Stops-Shapefile/pxug-u72f
dbf1 = Dbf5('Datasets/CTA_BusStops.dbf', codec='utf-8')

# %%
# take a look at the file
dbf1.fields
# Out:
# [('DeletionFlag', 'C', 1),
#  ('OBJECTID', 'N', 10),
#  ('SYSTEMSTOP', 'N', 19),
#  ('STREET', 'C', 75),
#  ('CROSS_ST', 'C', 75),
#  ('DIR', 'C', 3),
#  ('POS', 'C', 4),
#  ('ROUTESSTPG', 'C', 75),
#  ('OWLROUTES', 'C', 20),
#  ('CITY', 'C', 20),
#  ('STATUS', 'N', 10),
#  ('PUBLIC_NAM', 'C', 75),
#  ('POINT_X', 'N', 19),
#  ('POINT_Y', 'N', 19)]

# %%
# export .dbf file to .csv (BusStops)
dbf1.to_csv('Datasets/CTA_BusStops.csv')

# %%
# read .csv for BusStops
BusStops = pd.read_csv('Datasets/CTA_BusStops.csv', index_col = 'OBJECTID')

# %%
# import CTA_TrainStops.csv
# retrieved from GitHub
# originally downloaded from https://data.cityofchicago.org/Transportation/CTA-System-Information-List-of-L-Stops/8pix-ypme
TrainStops = pd.read_csv('Datasets/CTA_TrainStops.csv', index_col = 'STOP_ID')
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O                 Location
# STOP_ID
# 30162    False  False  False  False   True  False  (41.857908, -87.669147)
# 30161    False  False  False  False   True  False  (41.857908, -87.669147)
# 30022    False  False  False  False  False   True  (41.829353, -87.680622)
# 30023    False  False  False  False  False   True  (41.829353, -87.680622)
# 30214    False  False  False  False  False  False  (41.831677, -87.625826)

# %% [markdown]
# ## Step 7: Clean BusStop and TrainStop data

# %% [markdown]
# ### 7.1 BusStops data frame

# %%
# change column name POINT_X and POINT_Y to lat latitude longitude
BusStops = BusStops.rename(columns={"POINT_X": "longitude", "POINT_Y":"latitude"})

# %%
# look at clean data frame
BusStops.head()
# Out:
#          SYSTEMSTOP   STREET            CROSS_ST DIR POS ROUTESSTPG OWLROUTES  \
# OBJECTID
# 193          6696.0   TAYLOR              THROOP  EB  NS        157       NaN
# 194            22.0  JACKSON              KARLOV  EB  FS        126       NaN
# 195          4767.0   FOSTER          MONTICELLO  EB  NS         92       NaN
# 196          6057.0  ASHLAND  CERMAK/BLUE ISLAND  SB  NS       9,X9        N9
# 197          1790.0    CLARK              ALBION  SB  NS         22       N22
#
#              CITY STATUS                    PUBLIC_NAM     longitude  \
# OBJECTID
# 193       CHICAGO      1               Taylor & Throop  -87.65929365
# 194       CHICAGO      1              Jackson & Karlov  -87.72780787
# 195       CHICAGO      1           Foster & Monticello     -87.71978
# 196       CHICAGO      1  Ashland & Cermak/Blue Island  -87.66617293
# 197       CHICAGO      1                Clark & Albion  -87.67198065
#
#              latitude
# OBJECTID
# 193       41.86931425
# 194        41.8770066
# 195         41.975526
# 196       41.85248368
# 197       42.00178504

# %% [markdown]
# ### 7.2 TrainStops data frame

# %%
# split location into Point_X and Point_Y columns
LocationNew = TrainStops["Location"].str.split(",", n = 1, expand = True)
LocationNew.head()
# Out:
#                   0             1
# STOP_ID
# 30162    (41.857908   -87.669147)
# 30161    (41.857908   -87.669147)
# 30022    (41.829353   -87.680622)
# 30023    (41.829353   -87.680622)
# 30214    (41.831677   -87.625826)

# %%
# remove parentheses
LocationNew[0].replace(regex=True,inplace=True,to_replace=r'\(',value=r'')
LocationNew[1].replace(regex=True,inplace=True,to_replace=r'\)',value=r'')
LocationNew.head()
# Out:
#                  0            1
# STOP_ID
# 30162    41.857908   -87.669147
# 30161    41.857908   -87.669147
# 30022    41.829353   -87.680622
# 30023    41.829353   -87.680622
# 30214    41.831677   -87.625826

# %%
# add Point_Y and Point_X to dataframe
TrainStops["latitude"] = LocationNew[0]
TrainStops["longitude"] = LocationNew[1]
TrainStops = TrainStops.drop("Location", 1)

# %%
# look at clean TrainStops data frame
TrainStops.head()
# Out:
#         DIRECTION_ID                        STOP_NAME          STATION_NAME  \
# STOP_ID
# 30162              W         18th (54th/Cermak-bound)                  18th
# 30161              E                18th (Loop-bound)                  18th
# 30022              N         35th/Archer (Loop-bound)           35th/Archer
# 30023              S       35th/Archer (Midway-bound)           35th/Archer
# 30214              S  35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
#
#                   STATION_DESCRIPTIVE_NAME  MAP_ID   ADA    RED   BLUE      G  \
# STOP_ID
# 30162                     18th (Pink Line)   40830  True  False  False  False
# 30161                     18th (Pink Line)   40830  True  False  False  False
# 30022            35th/Archer (Orange Line)   40120  True  False  False  False
# 30023            35th/Archer (Orange Line)   40120  True  False  False  False
# 30214    35th-Bronzeville-IIT (Green Line)   41120  True  False  False   True
#
#            BRN      P   Pexp      Y    Pnk      O   latitude    longitude
# STOP_ID
# 30162    False  False  False  False   True  False  41.857908   -87.669147
# 30161    False  False  False  False   True  False  41.857908   -87.669147
# 30022    False  False  False  False  False   True  41.829353   -87.680622
# 30023    False  False  False  False  False   True  41.829353   -87.680622
# 30214    False  False  False  False  False  False  41.831677   -87.625826

# %% [markdown]
# ## Step 8: Assign GridID to BusStop and TrainStop data

# %% [markdown]
# ## Step 9: Load holiday data

# %% [markdown]
# ## Step 10: Clean holiday data

# %% [markdown]
# ## Step 11: Load tables into CloudSQL

# %%
# create test table
test = BusStops.loc[:, ["STREET"]]
test = test[193:195]
test = test.astype({"STREET": str})
test
# Out:
#             STREET
# OBJECTID
# 68        HARRISON
# 69          CICERO

# %%
# create connection to CloudSQL
engine = db.create_engine('mysql+pymysql://root:patronus@146.148.80.202/test')
connection = engine.connect()
metadata = db.MetaData()

# %%
# push data into CloudSQL table; change if_exist in case no data exists
test.to_sql('bus', con=engine, if_exists='append')

# %%
## WARNING: only run this when neccessary as this will be charged
# pull data from CloudSQL table

# define table
bus = db.Table('bus', metadata, autoload=True, autoload_with=engine)

# query the table
query = db.select([bus])
ResultProxy = connection.execute(query)
ResultProxy.fetchall()
# Out:
# [('68', 'HARRISON'), ('69', 'CICERO')]

# %% [markdown]
# ## Step 12: Daily refresh of crime data

# %%
# pull most recent date from table

latest_date = crime.date.max()
latest_date
# Out:
# '2019-11-11T23:59:00.000'

# %%
# prepare API statement: filter for dates that are more recent than the max date in the table

updated_statement = "date" + " " + ">" + " " + "'" + latest_date + "'"
updated_statement
# Out:
# "date > '2019-11-11T23:59:00.000'"

# %%
# Pull all crime data before '2019-11-15T00:00:00.000'
client = Socrata("data.cityofchicago.org",
                  "QtMhXqaTTglPlVS3AC6PEQQxD", username = "juli.kleindiek@gmail.com", password = "DEPA_2019")

# Limit to 5 rows for test purposes
results = client.get("5xiy-qnsz", where = updated_statement, limit = 5)

# %%
# Prepare new data (only example)
crime_new_dirty = pd.DataFrame.from_records(results)
crime_new = crime_new_dirty[['id', 
        'case_number', 
        'date', 
        'block', 
        'iucr', 
        'primary_type', 
        'description', 
        'location_description',
        'arrest',
        'domestic',
        'beat',
        'district',
        'ward',
        'community_area',
        'fbi_code',
        'x_coordinate',
        'y_coordinate',
        'year',
        'updated_on',
        'latitude',
        'longitude']]
crime_new.tail()

# %%
# Append new data to master crime data file
crime.append(crime_new)

# %% [markdown]
# ## Step 13: Clean daily updated crime data

# %% [markdown]
# ## Step 14: Assign GridID to daily updated crime data

# %% [markdown]
# ## Step 15: Append daily updated crime data to the crime database in CloudSQL
