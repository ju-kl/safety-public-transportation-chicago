# %%
# import requests library
from sodapy import Socrata
import pandas as pd

# %%
# API instructions https://dev.socrata.com/foundry/data.cityofchicago.org/ijzp-q8t2
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
# client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata("data.cityofchicago.org",
                  "QtMhXqaTTglPlVS3AC6PEQQxD", username = "juli.kleindiek@gmail.com", password = "DEPA_2019")

# Limit to 7000 rows to avoid time out errors, data has <7,000 rows, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("5xiy-qnsz", limit = 7000)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
# ...

# %%
crime_dirty = pd.DataFrame.from_records(results)

# %%
crime_dirty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 30 columns):
# :@computed_region_43wa_7qmu    5815 non-null object
# :@computed_region_6mkv_f3dw    5825 non-null object
# :@computed_region_awaf_s7ux    5812 non-null object
# :@computed_region_bdys_3d7i    5818 non-null object
# :@computed_region_d3ds_rm58    5816 non-null object
# :@computed_region_d9mm_jgwp    5816 non-null object
# :@computed_region_rpca_8um6    5815 non-null object
# :@computed_region_vrxf_vc4k    5815 non-null object
# arrest                         6000 non-null bool
# beat                           6000 non-null object
# block                          6000 non-null object
# case_number                    6000 non-null object
# community_area                 6000 non-null object
# date                           6000 non-null object
# description                    6000 non-null object
# district                       6000 non-null object
# ...

# %%
crime = crime_dirty[['id', 
        'case_number', 
        'date', 
        'block', 
        'iucr', 
        'primary_type', 
        'description', 
        'location_description',
        'arrest',
        'domestic',
        'beat',
        'district',
        'ward',
        'community_area',
        'fbi_code',
        'x_coordinate',
        'y_coordinate',
        'year',
        'updated_on',
        'latitude',
        'longitude']]

# %%
crime
# Out:
#            id case_number                     date  \
# 0     8256302    HT490196  2011-09-10T12:46:00.000
# 1     7979411    HT212010  2011-03-20T13:00:00.000
# 2     7981270    HT213521  2011-03-20T15:00:00.000
# 3     7979660    HT212325  2011-03-20T20:09:00.000
# 4     7989927    HT213271  2011-03-20T20:57:00.000
# 5     8332454    HT566424  2011-10-30T09:00:00.000
# 6     8332084    HT566137  2011-10-30T02:08:00.000
# 7     7905059    HT134917  2011-01-25T14:30:00.000
# 8     7906391    HT136142  2011-01-25T15:00:00.000
# 9     7982963    HT214882  2011-03-21T14:30:00.000
# 10    7908516    HT137954  2011-01-25T15:00:00.000
# 11    7981295    HT213619  2011-03-21T17:35:00.000
# 12    8331651    HT565471  2011-10-29T15:29:00.000
# 13    7986020    HT217594  2011-03-21T19:00:00.000
# 14    7869656    HT100245  2011-01-01T02:50:00.000
# 15    7907026    HT136391  2011-01-25T17:56:00.000
# 16    8413942    HT643325  2011-12-22T12:45:00.000
# ...
